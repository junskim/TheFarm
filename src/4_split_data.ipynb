# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.cross_validation import train_test_split
import numpy as np
from numpy import float32
from sklearn.metrics import precision_score, recall_score, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the table

# %%
df = pd.read_csv('Data/Players/cleaned_data_ver2.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.shape
# Out:
# (255997, 99)

# %%
df['Rookie?'].value_counts(dropna=False)  # class imbalance
# Out:
# 0    252834
# 1      3163
# Name: Rookie?, dtype: int64

# %%
df.columns
# Out:
# Index([u'Rookie?', u'player_id', u'Name', u'Height', u'Weight', u'Drafted',
#        u'Catcher', u'Centerfielder', u'Designated', u'First', u'Hitter',
#        u'Leftfielder', u'N/A', u'Outfielder', u'Pitcher', u'Rightfielder',
#        u'Second', u'Shortstop', u'Third', u'Bats_both', u'Bats_left',
#        u'Bats_Right', u'Bats_unknown', u'Throws_left', u'Throws_right',
#        u'Throws_unknown', u'Year', u'Age_batting', u'AgeDif_batting', u'Tm',
#        u'Lg_batting', u'Lev', u'Aff_batting', u'G_batting', u'PA', u'AB',
#        u'R_batting', u'H_batting', u'2B', u'3B', u'HR_batting', u'RBI',
#        u'SB_batting', u'CS_batting', u'BB_batting', u'SO_batting', u'BA',
#        u'OBP', u'SLG', u'OPS', u'TB', u'GDP', u'HBP_batting', u'SH', u'SF',
#        u'IBB_batting', u'Age_pitching', u'AgeDif_pitching', u'Lg_pitching',
#        u'Aff_pitching', u'W', u'L', u'ERA', u'RAvg', u'G_pitching', u'GS',
#        u'GF', u'CG', u'SHO', u'SV', u'IP', u'H_pitching', u'R_pitching', u'ER',
#        u'HR_pitching', u'BB_pitching', u'IBB_pitching', u'SO_pitching',
#        u'HBP_pitching', u'BK', u'WP', u'BF', u'WHIP', u'H9', u'HR9', u'BB9',
#        u'SO9', u'SO/W', u'Fielding_position', u'G', u'Ch', u'A', u'E', u'DP',
#        u'Fld_perc', u'RF/G', u'SB_fielding', u'CS_fielding', u'CS_perc'],
#       dtype='object')

# %% [markdown]
# # Splitting batters and pitchers

# %%
for i, v in enumerate(list(df.columns)):
    if v == 'Age_batting':
        print 'batting starts at: ' + str(i)
    if v == 'Lev':
        print 'pitching stats at: ' + str(i)
    if v == 'Age_pitching':
        print 'pitching stats at: ' + str(i)
    if v == 'Fielding_position':
        print 'fielding starts at: ' + str(i)
    if v == 'Tm':
        print 'Tm column has index of: ' + str(i)
# Out:
# batting starts at: 27
# Tm column has index of: 29
# pitching stats at: 31
# pitching stats at: 56
# fielding starts at: 88

# %%
pit_columns = df.columns - df.columns[27:28] - df.columns[30:31] - df.columns[32:56]  # these are the pitchers
# Out:
# /home/jun/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: using '-' to provide set differences with Indexes is deprecated, use .difference()
#   if __name__ == '__main__':

# %%
bat_columns = df.columns - df.columns[57:88]  # these are the batters (positional players)
# Out:
# /home/jun/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: using '-' to provide set differences with Indexes is deprecated, use .difference()
#   if __name__ == '__main__':

# %%
pit = df[df['Pitcher'] == 1][pit_columns]

# %%
bat = df[df['Pitcher'] == 0][bat_columns]

# %%
pit.shape
# Out:
# (130153, 73)

# %%
bat.shape
# Out:
# (125844, 68)

# %% [markdown]
# ### Saving to two different csv files

# %%
bat.to_csv('/home/jun/Galvanize/capstone/Galvanize_capstone/Data/Players/batters.csv')

# %%
pit.to_csv('/home/jun/Galvanize/capstone/Galvanize_capstone/Data/Players/pitchers.csv')

# %% [markdown]
# ------------------------------

# %%
df[(df['Lev'] != 'Fgn') & (df['Lev'] != 'Ind') & (df['Lev'] != 'FgW') &
   (df['Lev'] != 'Fal') & (df['Lev'] != 'FRk') & (df['Lev'] != 'WRk')].shape
# Out:
# (193193, 99)

# %%
df.Lev.unique()
# Out:
# array(['Fgn', 'Rk', 'A', 'A+', 'FgW', 'Ind', 'AA', 'AAA', 'A-', 'Fal',
#        'FRk', 'WRk', 'MLB'], dtype=object)

# %%
df[['Name', 'Year', 'Tm', 'Lev']]
# Out:
#                      Name  Year               Tm  Lev
# 0         Frank Del Valle  2007     Industriales  Fgn
# 1         Frank Del Valle  2008   Metropolitanos  Fgn
# 2         Frank Del Valle  2011             Cubs   Rk
# 3         Frank Del Valle  2011           Peoria    A
# 4         Frank Del Valle  2011          Daytona   A+
# 5         Frank Del Valle  2012          Daytona   A+
# 6         Frank Del Valle  2013          Daytona   A+
# 7         Frank Del Valle  2013        Margarita  FgW
# 8         Frank Del Valle  2014          Wichita  Ind
# 9         Frank Del Valle  2014        Margarita  FgW
# 10        Frank Del Valle  2015           Joplin  Ind
# 11        Darren Dreifort  1994       SanAntonio   AA
# 12        Darren Dreifort  1994      Albuquerque  AAA
# 13        Darren Dreifort  1996      Albuquerque  AAA
# 14        Darren Dreifort  1997      Albuquerque  AAA
# 15        Brian Cleveland  2004        Jamestown   A-
# 16        Brian Cleveland  2004        Jamestown   A-
# 17        Brian Cleveland  2004        Jamestown   A-
# 18        Brian Cleveland  2004        Jamestown   A-
# 19        Brian Cleveland  2005       Greensboro    A
# 20        Brian Cleveland  2005       Greensboro    A
# 21        Brian Cleveland  2006          Jupiter   A+
# 22        Brian Cleveland  2006          Jupiter   A+
# 23        Brian Cleveland  2006         Carolina   AA
# 24        Brian Cleveland  2006         Carolina   AA
# 25        Brian Cleveland  2006  PeoriaJavelinas  Fal
# 26            Jeff Bieker  2005        Vancouver   A-
# 27            Jeff Bieker  2005        Vancouver   A-
# 28            Jeff Bieker  2006       KaneCounty    A
# 29            Jeff Bieker  2006       KaneCounty    A
# ...                   ...   ...              ...  ...
# 406198   Mike Yastrzemski  2016            Bowie   AA
# 406199   Mike Yastrzemski  2016            Bowie   AA
# 406200   Mike Yastrzemski  2016            Bowie   AA
# 406201   Mike Yastrzemski  2016          Norfolk  AAA
# 406202   Mike Yastrzemski  2016          Norfolk  AAA
# 406203   Mike Yastrzemski  2016          Norfolk  AAA
# 406204   Mike Yastrzemski  2016          Norfolk  AAA
# 406205  Tetsuya Yamaguchi  2002         Missoula   Rk
# 406206  Tetsuya Yamaguchi  2003         Missoula   Rk
# 406207  Tetsuya Yamaguchi  2004         Missoula   Rk
# 406208  Tetsuya Yamaguchi  2007          Yomiuri  Fgn
# 406209  Tetsuya Yamaguchi  2008          Yomiuri  Fgn
# 406210  Tetsuya Yamaguchi  2009          Yomiuri  Fgn
# 406211  Tetsuya Yamaguchi  2010          Yomiuri  Fgn
# 406212  Tetsuya Yamaguchi  2011          Yomiuri  Fgn
# 406213  Tetsuya Yamaguchi  2012          Yomiuri  Fgn
# 406214  Tetsuya Yamaguchi  2013          Yomiuri  Fgn
# 406215  Tetsuya Yamaguchi  2014          Yomiuri  Fgn
# 406216  Tetsuya Yamaguchi  2015          Yomiuri  Fgn
# 406217    Gustavo Zarraga  2006           RedSox  FRk
# 406218         Jeff Yoder  1996         Rockford    A
# 406219         Jeff Yoder  1998          Daytona   A+
# 406220         Jeff Yoder  1999          Daytona   A+
# 406221         Jeff Yoder  1999         WestTenn   AA
# 406222         Jeff Yoder  2000         WestTenn   AA
# 406223    Malique Ziegler  2016           Giants   Rk
# 406224    Malique Ziegler  2016           Giants   Rk
# 406225    Malique Ziegler  2016           Giants   Rk
# 406226          Trey York  2016          Brewers   Rk
# 406227          Trey York  2016          Brewers   Rk
#
# [406228 rows x 4 columns]

# %%
bat[bat.A.isnull()].shape
# Out:
# (2441, 67)

# %%
pit[pit.SV == 1][['Lev', 'W', 'SV', 'G_pitching', 'GS', 'IP']]
# Out:
#         Lev     W   SV  G_pitching    GS     IP
# 33      FRk   1.0  1.0        11.0   1.0   26.2
# 67      AAA   2.0  1.0        38.0   0.0   44.2
# 120      Rk   1.0  1.0        14.0   8.0   51.2
# 121      A+   3.0  1.0        26.0  10.0   79.2
# 161      A-   4.0  1.0        14.0  11.0   61.1
# 162       A   6.0  1.0        32.0  15.0  117.2
# 168      Rk   1.0  1.0        18.0   0.0   24.2
# 182     Ind   0.0  1.0        10.0   0.0    9.0
# 254      A+   9.0  1.0        29.0   7.0   94.0
# 259      AA   0.0  1.0         7.0   4.0   30.1
# 264     Ind   0.0  1.0         6.0   0.0    7.1
# 272       A   4.0  1.0        20.0   2.0   53.0
# 292     AAA   0.0  1.0        20.0   1.0   33.0
# 326      Rk   1.0  1.0        17.0   0.0   22.1
# 335      A+   5.0  1.0        13.0  10.0   56.2
# 393     Ind  11.0  1.0        34.0  23.0  182.1
# 408      Rk   0.0  1.0         3.0   0.0    4.0
# 439     FRk   2.0  1.0        15.0   9.0   44.1
# 440      Rk   4.0  1.0        17.0   0.0   28.1
# 465      A+   3.0  1.0        19.0   0.0   30.1
# 471     AAA   3.0  1.0        35.0   8.0   95.0
# 486      A-   2.0  1.0        13.0   3.0   34.1
# 592      A+   1.0  1.0        40.0   0.0   64.0
# 596     AAA   0.0  1.0        15.0   0.0    8.0
# 606     AAA   3.0  1.0        27.0   0.0   33.0
# 610     AAA   1.0  1.0        26.0   0.0   32.0
# 683     AAA   2.0  1.0        63.0   0.0   82.1
# 715     FRk   0.0  1.0        14.0   0.0   16.2
# 718     FRk   1.0  1.0         8.0   1.0   13.0
# 746     Ind   1.0  1.0        23.0   0.0   38.1
# ...     ...   ...  ...         ...   ...    ...
# 255699    A   4.0  1.0        42.0   0.0   56.1
# 255707  FgW   0.0  1.0        11.0   0.0   12.0
# 255710  AAA   1.0  1.0        19.0   0.0   21.0
# 255711  AAA   5.0  1.0        20.0   0.0   26.1
# 255748    A   1.0  1.0        14.0   0.0   25.0
# 255750    A   3.0  1.0        26.0   0.0   36.1
# 255754  Ind   0.0  1.0         8.0   3.0   16.1
# 255762  FRk   2.0  1.0        16.0   3.0   41.0
# 255767   A+   1.0  1.0        23.0   0.0   31.0
# 255778   AA   7.0  1.0        23.0  11.0   95.1
# 255784  FgW   4.0  1.0        11.0   6.0   51.1
# 255789  Ind   4.0  1.0        13.0   9.0   66.1
# 255818   Rk   1.0  1.0        17.0   3.0   40.2
# 255822  AAA   1.0  1.0         2.0   0.0    3.2
# 255832  Fal   0.0  1.0         9.0   0.0   10.1
# 255840    A   4.0  1.0        20.0   0.0   33.1
# 255845   Rk   0.0  1.0         4.0   0.0    8.1
# 255847   A+   2.0  1.0        11.0   0.0   12.1
# 255848    A   6.0  1.0        35.0   1.0   72.2
# 255850    A   4.0  1.0        15.0   0.0   28.2
# 255874  Fgn   9.0  1.0        35.0  26.0  181.0
# 255876  Fgn   6.0  1.0        33.0  22.0  144.0
# 255881  Fgn   7.0  1.0        26.0  23.0  154.2
# 255882  Fgn  18.0  1.0        29.0  28.0  206.2
# 255891  Fgn  11.0  1.0        27.0  26.0  170.2
# 255911   AA   3.0  1.0        37.0   0.0   43.2
# 255955    A   7.0  1.0        33.0  10.0   89.1
# 255957   A+   1.0  1.0        32.0   0.0   49.0
# 255958   Rk   0.0  1.0         8.0   1.0   17.2
# 255992   A+   0.0  1.0         5.0   0.0   10.2
#
# [15251 rows x 6 columns]
